# %%
import pandas as pd

# %%
df = pd.read_csv("cool_results.csv")

# %%
df.shape
# Out:
# (227850, 7)

# %%
count_exo = (df['predicted_class'] == 'control').sum()
print(count_exo)
# Out:
# 171457

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227850 entries, 0 to 227849
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   wave             227850 non-null  float64
#  1   intensity        227850 non-null  float64
#  2   brain_region     227850 non-null  object
#  3   predicted_class  227850 non-null  object
#  4   proba_control    227850 non-null  float64
#  5   proba_endo       227850 non-null  float64
#  6   proba_exo        227850 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 12.2+ MB

# %%
df.head(100)
# Out:
#            wave     intensity brain_region predicted_class  proba_control  \
# 0   1699.966797  11496.750000   cerebellum             exo       0.244999
# 1   1698.950195  11356.371094   cerebellum             exo       0.173935
# 2   1697.932617  11349.275391   cerebellum             exo       0.206155
# 3   1696.915039  11440.852539   cerebellum             exo       0.213100
# 4   1695.897461  11384.416016   cerebellum             exo       0.197295
# ..          ...           ...          ...             ...            ...
# 95  1602.463867  11781.089844   cerebellum             exo       0.349267
# 96  1601.428711  11851.502930   cerebellum             exo       0.400452
# 97  1600.392578  12038.174805   cerebellum             exo       0.321294
# 98  1599.356445  11929.266602   cerebellum             exo       0.393906
# 99  1598.319336  11711.422852   cerebellum             exo       0.345356
#
#     proba_endo  proba_exo
# 0     0.158187   0.596813
# ...
